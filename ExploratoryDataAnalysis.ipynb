# %% [markdown]
# Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('housing_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0 Location                                              Title  \
# 0           0   Guelph   Two bedroom basement apartment for rent in so...
# 1           1   Guelph             One Bedroom Walkout Apartment for Rent
# 2           2   Guelph        The Chelsea  - 1 Bedroom Apartment for Rent
# 3           3   Guelph        The Chelsea  - 2 Bedroom Apartment for Rent
# 4           4   Guelph     996 Paisley Rd. - 1 Bedroom Apartment for Rent
#
#    Price       Style Bedrooms  Bathrooms Size(sqft) Air Conditioned   Den  \
# 0   1700    Basement        2        1.0        800                No  No
# 1   1895   Apartment        1        1.0    Limited                No  No
# 2   2381   Apartment        1        1.0        721               Yes  No
# 3   2798   Apartment        2        2.0       1002               Yes  No
# 4   2250   Apartment        1        1.0        710               Yes  No
#
#   Bachelor/Studio
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No

# %% [markdown]
# Data Cleaning

# %%
df2 = pd.read_csv('housing_cleaned.csv')

df2 = df2[df2["Size(sqft)"].str.contains("N/A") == False]
df2 = df2[df2["Size(sqft)"].str.contains("Limited") == False]
df2= df2[df2["Bedrooms"].str.contains("5+") == False]
df = df[df["Bedrooms"].str.contains("5+") == False]

# %%
df2['Bedrooms'] = df2["Bedrooms"].astype(float)
df2['Bathrooms'] = df2["Bathrooms"].astype(float)
df['Bedrooms'] = df["Bedrooms"].astype(float)
df['Bathrooms'] = df["Bathrooms"].astype(float)

# %% [markdown]
# Scatterplots

# %%
df2['Price'] = df2["Price"].astype(float)
df2['Size(sqft)'] = df2["Size(sqft)"].astype(float)

sns.scatterplot(data=df2, x="Size(sqft)", y="Price", hue="Location").set(title = 'Price per Square Footage in Ontario University Cities')
# Out:
# [Text(0.5, 1.0, 'Price per Square Footage in Ontario University Cities')]

# %% [markdown]
# Heatmaps

# %%
sns.heatmap(df2[['Price', 'Size(sqft)', 'Bedrooms', 'Bathrooms']].corr(), annot=True).set(title = 'Key Values Heatmap')
# Out:
# [Text(0.5, 1.0, 'Key Values Heatmap')]

# %% [markdown]
# Bar Graphs

# %%
sns.barplot(data=df, x="Bedrooms", y="Price", hue="Location").set(title = 'Bedroom Number Affect on Pricing Per City')
# Out:
# [Text(0.5, 1.0, 'Bedroom Number Affect on Pricing Per City')]

# %%
sns.barplot(data=df, x="Bathrooms", y="Price", hue="Location").set(title = 'Bathroom Number Affect on Pricing Per City')
# Out:
# [Text(0.5, 1.0, 'Bathroom Number Affect on Pricing Per City')]

# %%
sns.barplot(data=df2, x="Bedrooms", y="Size(sqft)", hue="Location").set(title = 'Bedroom correlation to Square Footage Per City')
# Out:
# [Text(0.5, 1.0, 'Bedroom correlation to Square Footage Per City')]

# %%
sns.barplot(data=df2, x="Bathrooms", y="Size(sqft)", hue="Location").set(title = 'Bathroom correlation to Square Footage Per City')
# Out:
# [Text(0.5, 1.0, 'Bathroom correlation to Square Footage Per City')]

# %%
sns.barplot(data=df, x="Den", y="Price", hue="Bedrooms").set(title = 'Den Affect on Pricing Per City')
# Out:
# [Text(0.5, 1.0, 'Den Affect on Pricing Per City')]

# %%
sns.barplot(data=df2, x="Den", y="Size(sqft)", hue="Bedrooms").set(title = 'Den correlation to Square Footage Per City')
# Out:
# [Text(0.5, 1.0, 'Den correlation to Square Footage Per City')]

# %%
sns.barplot(data=df, x="Style", y="Price", hue="Location").set(title = 'Style of Listing correlation to Price Per City')
# Out:
# [Text(0.5, 1.0, 'Style of Listing correlation to Price Per City')]

# %%
sns.barplot(data=df2, x="Style", y="Size(sqft)", hue="Location").set(title = 'Style of Listing correlation to Square Footage Per City')
# Out:
# [Text(0.5, 1.0, 'Style of Listing correlation to Square Footage Per City')]

# %%
sns.barplot(data=df, x="Location", y="Price").set(title = 'Average Prices of Listings per City ')
# Out:
# [Text(0.5, 1.0, 'Average Prices of Listings per City ')]

# %%
sns.barplot(data=df2, x="Location", y="Size(sqft)").set(title = 'Average Square Footage of Listings per City')
# Out:
# [Text(0.5, 1.0, 'Average Square Footage of Listings per City')]

# %%
sns.barplot(data=df, x="Location", y="Bedrooms").set(title = 'Average Bedrooms of Listings per City')
# Out:
# [Text(0.5, 1.0, 'Average Bedrooms of Listings per City')]

# %%
sns.barplot(data=df, x="Location", y="Bathrooms").set(title = 'Average Bathrooms of Listings per City')
# Out:
# [Text(0.5, 1.0, 'Average Bathrooms of Listings per City')]

# %% [markdown]
# Pivot Tables

# %%
pd.pivot_table(df, index = ['Location'], values = 'Price')
# Out:
#                  Price
# Location
# Guelph     2124.380952
# Hamilton   1975.027778
# Kitchener  2215.716279
# London     2010.442786
# Ottawa     1995.655280
# Toronto    2347.425926

# %%
pd.pivot_table(df, index = ['Location', 'Bedrooms'], values = 'Price')
# Out:
#                           Price
# Location  Bedrooms
# Guelph    0.0       1795.000000
#           1.0       2018.755556
#           2.0       2223.857143
#           3.0       2658.000000
# Hamilton  0.0       1284.857143
#           1.0       1721.907692
#           2.0       2208.625000
#           3.0       2620.214286
#           4.0       1560.000000
# Kitchener 0.0       1625.000000
#           1.0       1838.830769
#           2.0       2267.148515
#           3.0       2594.944444
#           4.0       3291.250000
# London    0.0       1293.800000
#           1.0       1485.396226
#           2.0       1871.486111
#           3.0       2518.105263
#           4.0       2901.785714
# Ottawa    0.0       1549.862069
#           1.0       1755.623288
#           2.0       2246.876106
#           3.0       2596.354839
#           4.0       2316.666667
# Toronto   0.0       1872.724138
#           1.0       2190.710280
#           2.0       2615.463768
#           3.0       3406.200000
#           4.0       3800.000000
