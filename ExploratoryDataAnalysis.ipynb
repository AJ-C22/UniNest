# %% [markdown]
# Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('housing_cleaned.csv')
df.head()
# Out:
#    Unnamed: 0 Location                                              Title  \
# 0           0   Guelph   Two bedroom basement apartment for rent in so...
# 1           1   Guelph             One Bedroom Walkout Apartment for Rent
# 2           2   Guelph        The Chelsea  - 1 Bedroom Apartment for Rent
# 3           3   Guelph        The Chelsea  - 2 Bedroom Apartment for Rent
# 4           4   Guelph     996 Paisley Rd. - 1 Bedroom Apartment for Rent
#
#    Price       Style Bedrooms  Bathrooms Size(sqft) Air Conditioned   Den  \
# 0   1700    Basement        2        1.0        800                No  No
# 1   1895   Apartment        1        1.0    Limited                No  No
# 2   2381   Apartment        1        1.0        721               Yes  No
# 3   2798   Apartment        2        2.0       1002               Yes  No
# 4   2250   Apartment        1        1.0        710               Yes  No
#
#   Bachelor/Studio
# 0              No
# 1              No
# ...

# %% [markdown]
# Data Cleaning

# %%
df2 = pd.read_csv('housing_cleaned.csv')

df2 = df2[df2["Size(sqft)"].str.contains("N/A") == False]
df2 = df2[df2["Size(sqft)"].str.contains("Limited") == False]
df2= df2[df2["Bedrooms"].str.contains("5+") == False]
df = df[df["Bedrooms"].str.contains("5+") == False]

# %%
df2['Bedrooms'] = df2["Bedrooms"].astype(float)
df2['Bathrooms'] = df2["Bathrooms"].astype(float)
df['Bedrooms'] = df["Bedrooms"].astype(float)
df['Bathrooms'] = df["Bathrooms"].astype(float)

# %% [markdown]
# Scatterplots

# %%
df2['Price'] = df2["Price"].astype(float)
df2['Size(sqft)'] = df2["Size(sqft)"].astype(float)

sns.scatterplot(data=df2, x="Size(sqft)", y="Price", hue="Location").set(title = 'Price per Square Footage in Ontario University Cities')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 4
#       1 df2['Price'] = df2["Price"].astype(float)
#       2 df2['Size(sqft)'] = df2["Size(sqft)"].astype(float)
# ----> 4 sns.scatterplot(data=df2, x="Size(sqft)", y="Price", hue="Location").set(title = 'Price per Square Footage in Ontario University Cities').set(ylabel = 'Price($)')
#
# AttributeError: 'list' object has no attribute 'set'

# %% [markdown]
# Heatmaps

# %%
sns.heatmap(df2[['Price', 'Size(sqft)', 'Bedrooms', 'Bathrooms']].corr(), annot=True).set(title = 'Key Values Heatmap')
# Out:
# [Text(0.5, 1.0, 'Key Values Heatmap')]

# %% [markdown]
# Bar Graphs

# %%
sns.barplot(data=df2, x="Bedrooms", y="Price", hue="Location").set(title = 'Bedroom Number Affect on Pricing Per City')
# Out:
# [Text(0.5, 1.0, 'Bedroom Number Affect on Pricing Per City')]

# %%
sns.barplot(data=df2, x="Bathrooms", y="Price", hue="Location").set(title = 'Bathroom Number Affect on Pricing Per City')
# Out:
# <Axes: xlabel='Bathrooms', ylabel='Price'>

# %%
sns.barplot(data=df2, x="Bedrooms", y="Size(sqft)", hue="Location").set(title = 'Bedroom correlation to Square Footage Per City')
# Out:
# <Axes: xlabel='Bedrooms', ylabel='Size(sqft)'>

# %%
sns.barplot(data=df2, x="Bathrooms", y="Size(sqft)", hue="Location").set(title = 'Bathroom correlation to Square Footage Per City')
# Out:
# <Axes: xlabel='Bathrooms', ylabel='Size(sqft)'>

# %%
sns.barplot(data=df2, x="Den", y="Price", hue="Bedrooms").set(title = 'Den Affect on Pricing Per City')
# Out:
# <Axes: xlabel='Den', ylabel='Price'>

# %%
sns.barplot(data=df2, x="Den", y="Size(sqft)", hue="Bedrooms").set(title = 'Den correlation to Square Footage Per City')
# Out:
# <Axes: xlabel='Den', ylabel='Size(sqft)'>

# %%
sns.barplot(data=df2, x="Style", y="Price", hue="Location").set(title = 'Style of Listing correlation to Price Per City')
# Out:
# <Axes: xlabel='Style', ylabel='Price'>

# %%
sns.barplot(data=df2, x="Style", y="Size(sqft)", hue="Location").set(title = 'Style of Listing correlation to Square Footage Per City')
# Out:
# <Axes: xlabel='Style', ylabel='Size(sqft)'>

# %%
sns.barplot(data=df2, x="Location", y="Price").set(title = 'Average Prices of Listings per City ')
# Out:
# [Text(0.5, 1.0, 'Average Prices of Listings per City ')]

# %%
sns.barplot(data=df2, x="Location", y="Size(sqft)").set(title = 'Average Square Footage of Listings per City')
# Out:
# <Axes: xlabel='Location', ylabel='Size(sqft)'>

# %%
sns.barplot(data=df2, x="Location", y="Bedrooms").set(title = 'Average Bedrooms of Listings per City')
# Out:
# <Axes: xlabel='Location', ylabel='Bedrooms'>

# %%
sns.barplot(data=df2, x="Location", y="Bathrooms").set(title = 'Average Bathrooms of Listings per City')
# Out:
# <Axes: xlabel='Location', ylabel='Bathrooms'>

# %% [markdown]
# Pivot Tables

# %%
pd.pivot_table(df2, index = ['Location'], values = 'Price')
# Out:
#                  Price
# Location
# Guelph     2154.056338
# Hamilton   2014.747664
# Kitchener  2256.572327
# London     2028.682927
# Ottawa     1945.849558
# Toronto    2331.898089

# %%
pd.pivot_table(df2, index = ['Location', 'Bedrooms'], values = 'Price')
# Out:
#                           Price
# Location  Bedrooms
# Guelph    1.0       2058.486486
#           2.0       2243.333333
#           3.0       2744.000000
# Hamilton  0.0       1278.800000
#           1.0       1755.159091
#           2.0       2183.574468
#           3.0       2678.400000
#           4.0       2545.000000
# Kitchener 0.0       1475.000000
#           1.0       1846.760870
#           2.0       2271.617284
#           3.0       2805.958333
#           4.0       3258.333333
# London    0.0       1398.500000
#           1.0       1472.548387
#           2.0       1892.488889
#           3.0       2535.235294
#           4.0       2991.666667
# Ottawa    0.0       1517.840000
#           1.0       1734.049505
#           2.0       2201.620253
#           3.0       2511.857143
# Toronto   0.0       1904.333333
#           1.0       2153.506494
#           2.0       2623.765957
#           3.0       3433.375000
#           4.0       3800.000000
