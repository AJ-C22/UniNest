# %% [markdown]
# Exploratory Data Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('housing_cleaned.csv')
df.head()

# %% [markdown]
# Data Cleaning

# %%
df2 = pd.read_csv('housing_cleaned.csv')

df2 = df2[df2["Size(sqft)"].str.contains("N/A") == False]
df2 = df2[df2["Size(sqft)"].str.contains("Limited") == False]
df2= df2[df2["Bedrooms"].str.contains("5+") == False]
df = df[df["Bedrooms"].str.contains("5+") == False]

# %%
df2['Bedrooms'] = df2["Bedrooms"].astype(float)
df2['Bathrooms'] = df2["Bathrooms"].astype(float)
df['Bedrooms'] = df["Bedrooms"].astype(float)
df['Bathrooms'] = df["Bathrooms"].astype(float)

# %% [markdown]
# Scatterplots

# %%
df2['Price'] = df2["Price"].astype(float)
df2['Size(sqft)'] = df2["Size(sqft)"].astype(float)

sns.scatterplot(data=df2, x="Size(sqft)", y="Price", hue="Location")

# %% [markdown]
# Heatmaps

# %%
sns.heatmap(df2[['Price', 'Size(sqft)', 'Bedrooms', 'Bathrooms']].corr(), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Bar Graphs

# %%
sns.barplot(data=df2, x="Bedrooms", y="Price", hue="Location")

# %%
sns.barplot(data=df2, x="Bathrooms", y="Price", hue="Location")

# %%
sns.barplot(data=df2, x="Bedrooms", y="Size(sqft)", hue="Location")

# %%
sns.barplot(data=df2, x="Bathrooms", y="Size(sqft)", hue="Location")

# %%
sns.barplot(data=df2, x="Den", y="Price", hue="Bedrooms")

# %%
sns.barplot(data=df2, x="Den", y="Size(sqft)", hue="Bedrooms")

# %%
sns.barplot(data=df2, x="Style", y="Price", hue="Location")

# %%
sns.barplot(data=df2, x="Style", y="Size(sqft)", hue="Location")

# %%
df2.Style.hist()

# %%
sns.barplot(data=df2, x="Location", y="Price")

# %%
sns.barplot(data=df2, x="Location", y="Size(sqft)")

# %%
sns.barplot(data=df2, x="Location", y="Bedrooms")

# %%
sns.barplot(data=df2, x="Location", y="Bathrooms")
